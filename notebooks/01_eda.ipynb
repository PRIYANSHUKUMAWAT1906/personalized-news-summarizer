# %%
import json
import pandas as pd
# Out:
# Running cells with 'venv (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/DELL/OneDrive/Desktop/personalized-news-summarizer/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
