# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/clean_news_dataset.csv")

df.head()
# Out:
#                                                title  \
# 0  All the Ways Europe Is Ditching American Techn...
# 1  IBM Crosses One of Computing’s Biggest Barrier...
# 2  Meta Is Testing Police Surveillance Tech for I...
# 3  Trump Admin Declares Total Victory Over Algae ...
# 4  Elon Musk is steamrolling Wall Street to becom...
#
#                                          description  \
# 0  A WIRED timeline shows how dozens of governmen...
# 1  The new chip technology packs nearly 100 billi...
# 2  A report suggests ties between Meta's facial r...
# 3  "The Reflecting Pool water is crystal clear," ...
# 4  Today on Decoder, I’m talking to Ryan Mac, a t...
#
#                                              content    category  \
# 0  Europe is done with American Big Tech. Well, s...  technology
# 1  In a major breakthrough, IBM revealed the worl...  technology
# 2  Meta is finding inspiration for its smart glas...  technology
# 3  The U.S. may have lost its war against Iran, b...  technology
# 4  <ul><li></li><li></li><li></li></ul>\r\nThe Ne...  technology
#
#                                                 text
# 0  all the ways europe is ditching american techn...
# 1  ibm crosses one of computings biggest barriers...
# 2  meta is testing police surveillance tech for i...
# 3  trump admin declares total victory over algae ...
# 4  elon musk is steamrolling wall street to becom...

# %%
df.shape
df["category"].value_counts()
# Out:
# category
# science          93
# entertainment    91
# sports           89
# health           88
# business         82
# technology       68
# Name: count, dtype: int64

# %%
df["category"].value_counts().plot(kind="bar")

plt.title("Category Distribution")
plt.xlabel("Category")
plt.ylabel("Count")

plt.show()

# %%
df["text_length"] = df["text"].apply(len)
df["text_length"].describe()
df["text_length"].hist()

plt.title("Text Length Distribution")
plt.xlabel("Length")
plt.ylabel("Count")

plt.show()
